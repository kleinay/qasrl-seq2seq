# %% [markdown]
# # Miscelleneous
# Code for all sorts of thing that may be required again afterwards

# %%
import os
import sys
import pandas as pd
import numpy as np

import pprint
pp = pprint.PrettyPrinter(indent=2).pprint

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# Helper functions
def report_overlap(**kwargs):
    assert len(kwargs)==2
    (nm1, s1), (nm2, s2) = tuple(kwargs.items())
    s1, s2 = set(s1), set(s2)
    print(f"|{nm1}|={len(s1)}, |{nm2}|={len(s2)};   Union: {len(s1|s2)}  Intersection: {len(s1&s2)} ")
    print(f"|{nm1}-{nm2}|={len(s1-s2)}, |{nm2}-{nm1}|={len(s2-s1)};   ")

# %% [markdown]
# ## Evaluate nrl-parser output
#
# We took nrl-parser output on qasrl-gs test set (jsonl), converted to CSV using the `qasrl-state-machine` docker environment, and here we run the "qanom evaluation protocol" on it.

# %%
from datasets import load_dataset

qasrl_gs = load_dataset("biu-nlp/qa_srl2020")
test_set = qasrl_gs["test"]
df_gold = pd.DataFrame(test_set)
df_gold['qa_position'] = df_gold.groupby(["sent_id", "predicate_idx"]).cumcount()

df_parsed_predictions = pd.read_csv("../nrl_parser_output_qasrl_gs_test.csv")
df_parsed_predictions['qa_position'] = df_parsed_predictions.groupby(["qasrl_id", "verb_idx"]).cumcount()
df_parsed_predictions['qasrl_id'] = '---'
df_parsed_predictions['verb_form'] = '---'

# we have no alignment on the sentence or qasrl_id level,
# so we will sort by sentence string which should be sufficiently aligned
df_gold_sorted = df_gold.sort_values(by=['sentence', 'predicate_idx'])  
df_predictions_sorted = df_parsed_predictions.sort_values(by=['sentence', 'verb_idx'])
# Out:
# No config specified, defaulting to: qa_srl2020/default
# Reusing dataset qa_srl2020 (/home/nlp/kleinay/.cache/huggingface/datasets/biu-nlp___qa_srl2020/default/1.1.0/3b94572da7f8e6e95317517c89e9a702ba59775614c59c12d5d5cd3f6532b33a)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# report_overlap(pred=set(df_parsed_predictions.sentence), gold=set(df_gold.sentence))
missed_sents = []
missed_sents_pred = []
for gs, ps in zip(df_gold_sorted.sentence.unique(), df_predictions_sorted.sentence.unique()):
    if gs != ps:
        # print(gs, "\n"+ ps, "\n")
        missed_sents.append(gs)
        missed_sents_pred.append(ps)
real_misses = [89, 110, 505] # indexes found manually in `sent_mismatch.txt`, verified
real_missed_sents = [missed_sents[i] for i in real_misses]
df_gold_sorted_aligned = df_gold_sorted.loc[~df_gold_sorted.sentence.isin(real_missed_sents)]
# get qasrl_id
sent2id = {}
for gs, ps, qid in zip(df_gold_sorted_aligned.sentence.unique(), df_predictions_sorted.sentence.unique(), df_gold_sorted_aligned.sent_id.unique()):
    print(gs, "\n"+ ps, "\n")
    sent2id[ps] = qid
# set the right qasrl_id in predictions 
df_parsed_predictions["qasrl_id"] = df_parsed_predictions.apply(lambda r: sent2id[r.sentence], axis=1)


import evaluation
eval_measures = evaluation.run_qanom_evaluation(df_parsed_predictions.copy(), df_gold.copy())
# print(eval_measures[:3])
#** Evaluation Results:
# UA: P: 0.585   R: 0.445   F1: 0.505 
# A jury awarded Julie Miller of Marion County , Oregon $ 18.6 million last Friday in a federal lawsuit against Equifax .
#
# A large portion of the passenger area of the plane was on fire and has burned out .
# A large portion of the passenger area of the plane was on fire and has burned out .
#
# A non-passenger witness , Anthony Castorani , has reported that a fireball formed upon the plane landing and that the plane flipped over .
# A non - passenger witness , Anthony Castorani , has reported that a fireball formed upon the plane landing and that the plane flipped over .
#
# A number of event-causal accounts of free will have been created , referenced here as deliberative indeterminism , centred accounts , and efforts of will theory .
# A number of event - causal accounts of free will have been created , referenced here as deliberative indeterminism , centred accounts , and efforts of will theory .
#
# A number of professions have developed that specialize in the treatment of mental disorders .
# A number of professions have developed that specialize in the treatment of mental disorders .
#
# A parallel plate capacitor can only store a finite amount of energy before dielectric breakdown occurs .
# A parallel plate capacitor can only store a finite amount of energy before dielectric breakdown occurs .
#
# A petroleum company based in India , Oil and Natural Gas Corporation -LRB- ONGC -RRB- , operates in a number of oil blocks under South China Sea with consent of Vietnam , in the same Phu Khanh basin .
# A petroleum company based in India , Oil and Natural Gas Corporation -LRB- ONGC -RRB- , operates in a number of oil blocks under South China Sea with consent of Vietnam , in the same Phu Khanh basin .
#
# A presidential election is due this year and the constitution forbids a consecutive term for Martelly .
# A presidential election is due this year and the constitution forbids a consecutive term for Martelly .
#
# A quick jump was essential to minimise the risk of spinning out of control which could make the skydiver lose consciousness .
# A quick jump was essential to minimise the risk of spinning out of control which could make the skydiver lose consciousness .
#
# A raisin is any dried grape .
# A raisin is any dried grape .
#
# A report from French safety officials released on Wednesday said the co-pilot , Andreas Lubitz , practiced putting a plane into a controlled descent earlier in the day of the March 24 crash of Germanwings Flight 9525 , which officials allege the co-pilot caused by a controlled descent .
# A report from French safety officials released on Wednesday said the co - pilot , Andreas Lubitz , practiced putting a plane into a controlled descent earlier in the day of the March 24 crash of Germanwings Flight 9525 , which officials allege the co - pilot caused by a controlled descent .
#
# A second common objection to these models is that it is questionable whether such indeterminism could add any value to deliberation over that which is already present in a deterministic world .
# A second common objection to these models is that it is questionable whether such indeterminism could add any value to deliberation over that which is already present in a deterministic world .
#
# A spokesperson at Buckingham Palace said that `` The Queen was sad to hear the news of the death of Baroness Thatcher .
# A spokesperson at Buckingham Palace said that `` The Queen was sad to hear the news of the death of Baroness Thatcher .
#
# A subsequent crash wounded four .
# A subsequent crash wounded four .
#
# A sword bearing the name of pharaoh Merneptah as well as a battle axe with an iron blade and gold-decorated bronze shaft were both found in the excavation of Ugarit .
# A sword bearing the name of pharaoh Merneptah as well as a battle axe with an iron blade and gold - decorated bronze shaft were both found in the excavation of Ugarit .
#
# A universal declaration that specified the rights of individuals was necessary to give effect to the Charter 's provisions on human rights .
# A universal declaration that specified the rights of individuals was necessary to give effect to the Charter 's provisions on human rights .
#
# A vessel , flagged in Panama , suspected to be involved in the collision has been detained by the military .
# A vessel , flagged in Panama , suspected to be involved in the collision has been detained by the military .
#
# ASEAN sought economic integration by creating the AEC by the end of 2015 .
# ASEAN sought economic integration by creating the AEC by the end of 2015 .
# All of them impressed me as engineers who well understood the vital importance of their role in ensuring -LSB- ... -RSB- safety '' .
#
# All substances not possessing one of the other types of magnetism are diamagnetic ; this includes most substances .
# All substances not possessing one of the other types of magnetism are diamagnetic ; this includes most substances .
#
# All these texts describe Hindu renunciation and monastic values , and express strongly Advaita Vedanta tradition ideas .
# All these texts describe Hindu renunciation and monastic values , and express strongly Advaita Vedanta tradition ideas .
#
# Allosteric interactions with metabolites upstream or downstream in an enzyme 's metabolic pathway cause feedback regulation , altering the activity of the enzyme according to the flux through the rest of the pathway .
# Allosteric interactions with metabolites upstream or downstream in an enzyme 's metabolic pathway cause feedback regulation , altering the activity of the enzyme according to the flux through the rest of the pathway .
#
# Also due are municipal elections , with 4,000 local posts needing refilled .
# Also due are municipal elections , with 4,000 local posts needing refilled .
#
# Although force on a diamagnetic object from an ordinary magnet is far too weak to be felt , using extremely strong superconducting magnets , diamagnetic objects such as pieces of lead and even mice can be levitated , so they float in mid-air .
# Although force on a diamagnetic object from an ordinary magnet is far too weak to be felt , using extremely strong superconducting magnets , diamagnetic objects such as pieces of lead and even mice can be levitated , so they float in mid - air .
#
# Although often requested to write poems arousing nationalist passions , Goethe would always decline .
# Although often requested to write poems arousing nationalist passions , Goethe would always decline .
#
# Although the neural mechanisms of schizophrenia are not yet clear , one influential hypothesis is that there is a breakdown in brain systems that compare motor commands with the feedback received from the body -LRB- known as proprioception -RRB- , leading to attendant hallucinations and delusions of control .
# Although the neural mechanisms of schizophrenia are not yet clear , one influential hypothesis is that there is a breakdown in brain systems that compare motor commands with the feedback received from the body -LRB- known as proprioception -RRB- , leading to attendant hallucinations and delusions of control .
#
# Alvin Plantinga 's `` free will defense '' is a contemporary expansion of this theme , adding how God , free will , and evil are consistent .
# Alvin Plantinga 's `` free will defense '' is a contemporary expansion of this theme , adding how God , free will , and evil are consistent .
#
# Alzheimer 's disease is usually diagnosed based on the person 's medical history , history from relatives , and behavioural observations .
# Alzheimer 's disease is usually diagnosed based on the person 's medical history , history from relatives , and behavioural observations .
#
# Amanda Carter : I ` ll still keep playing women 's league , but not sure about some of the international stuff .
# Amanda Carter : I ` ll still keep playing women 's league , but not sure about some of the international stuff .
#
# Amanda Carter : I also in 2006 was readmitted back to hospital with another episode of transverse myelitis , which is my original disability , which then left me a C5 incomplete quad , so it then affected my right arm , in addition to the elbow injury .
# Amanda Carter : I also in 2006 was readmitted back to hospital with another episode of transverse myelitis , which is my original disability , which then left me a C5 incomplete quad , so it then affected my right arm , in addition to the elbow injury .
#
# Amanda Carter : The standard , over the years , has improved so much .
# Amanda Carter : The standard , over the years , has improved so much .
#
# Amanda Carter : We 've never won a gold , no .
# Amanda Carter : We ' ve never won a gold , no .
#
# Amanda Carter : We 've played a few .
# Amanda Carter : We ' ve played a few .
#
# American astronomer Edwin Hubble observed that the distances to faraway galaxies were strongly correlated with their redshifts .
# American astronomer Edwin Hubble observed that the distances to faraway galaxies were strongly correlated with their redshifts .
#
#
# But , as the evidence made clear , such a coincidence was indeed a possibility . ''
# But , as the evidence made clear , such a coincidence was indeed a possibility . ''
#
# But , of course , we need to fly in good weather and we carry only one pilot on board .
# But , of course , we need to fly in good weather and we carry only one pilot on board .
#
# But I have n't decided where to -LSB- go -RSB- from here .
# But I have n't decided where to -LSB- go -RSB- from here .
#
# But because that had occurred , they then said that they would not cover if my arm got hurt again .
# But because that had occurred , they then said that they would not cover if my arm got hurt again .
#
# But before he could take any action against the fake king -LRB- Indradatta in Nanda 's body , also called Yogananda -RRB- , the king had him arrested .
# But before he could take any action against the fake king -LRB- Indradatta in Nanda 's body , also called Yogananda -RRB- , the king had him arrested .
#
# But former New Hampshire State Senator Peter Burling argues Sanders can deliver with passion , something he says that Clinton lacks .
# ...
# ungrammatical question: what did someone invite someone to do? ; all core args are present in core-role active question.
# 972it [00:11, 91.14it/s]ungrammatical question: What did someone myek?
# 992it [00:11, 93.13it/s]ungrammatical question: What is something referred of?
# ungrammatical question: What is something derived from?
# 9it [00:00, 89.75it/s]  ungrammatical question: Who was something opposed by?
# 19it [00:00, 92.83it/s]ungrammatical question: When did something fell?
# ungrammatical question: What felled?
# ungrammatical question: What did something fell into?
# 39it [00:00, 93.83it/s]ungrammatical question: When isn't something be delayed?
# ungrammatical question: What did someone found?
# ungrammatical question: When did someone found something?
# ungrammatical question: Who founded something?
# 49it [00:00, 93.14it/s]ungrammatical question: What did something remain into?
# ungrammatical question: What wasn't something be recovered from?
# ungrammatical question: What did someone carry up?
# ungrammatical question: What did someone arrive at?
# 59it [00:00, 92.36it/s]ungrammatical question: Who was someone killed by?
# ungrammatical question: What was something followed by?
# 69it [00:00, 92.64it/s]ungrammatical question: What did someone die from?
# ungrammatical question: What did someone see?
# 79it [00:00, 92.05it/s]ungrammatical question: What has something churned up?
# 89it [00:00, 92.37it/s]ungrammatical question: What is someone staying at?
# ungrammatical question: What was someone involved in?
# ungrammatical question: What wasn't someone defend?
# ungrammatical question: When has someone be injured?
# 99it [00:01, 90.86it/s]ungrammatical question: What did someone hang into?
# ungrammatical question: What is something involved in?
# ungrammatical question: Where was something founded?
# ungrammatical question: Where was something founded?
# ungrammatical question: What was founded?
# ungrammatical question: What didn't someone have made?
# 109it [00:01, 90.04it/s]ungrammatical question: When will someone run?
# ungrammatical question: Where did something tyek something?
# 119it [00:01, 90.65it/s]ungrammatical question: What was someone appointed as?
# ungrammatical question: Who was someone joined by?
# 129it [00:01, 90.53it/s]ungrammatical question: What did something stir up?
# 139it [00:01, 90.95it/s]ungrammatical question: Who was someone murdered by?
# ungrammatical question: Who was something be introduced to?
# ungrammatical question: What is something be introduced to?
# 149it [00:01, 91.13it/s]ungrammatical question: Where was someone shotted?
# ungrammatical question: Where was someone shotted?
# ungrammatical question: When was someone shotted?
# ungrammatical question: Who was shotted?
# ungrammatical question: When was someone shotted somewhere?
# ungrammatical question: What was someone left with?
# ungrammatical question: What isn't be announced?
# 159it [00:01, 91.18it/s]ungrammatical question: What did someone resign from?
# ungrammatical question: What did someone retire from?
# 169it [00:01, 91.00it/s]ungrammatical question: What has something been lifted into?
# 179it [00:01, 90.67it/s]ungrammatical question: What has something relied on?
# ungrammatical question: Who is combat something?
# 189it [00:02, 89.83it/s]ungrammatical question: Who was someone encouraged by?
# 198it [00:02, 89.86it/s]ungrammatical question: Why did someone step up?
# ungrammatical question: Where did someone won something?
# ungrammatical question: What did someone won?
# ungrammatical question: How did someone won something?
# ungrammatical question: What was founded?
# ungrammatical question: Where was something founded?
# ungrammatical question: What wasn't someone challenge?
# 207it [00:02, 88.66it/s]ungrammatical question: What did someone claime?
# 247it [00:02, 92.11it/s]ungrammatical question: Who is something being spent with?
# ungrammatical question: What didn't someone have decided?
# 257it [00:02, 91.43it/s]ungrammatical question: What does someone keep  doing?
# ungrammatical question: What was someone looking through?
# 267it [00:02, 90.71it/s]ungrammatical question: When did someone go somewhere?
# ungrammatical question: Where did someone go?
# 277it [00:03, 90.15it/s]ungrammatical question: What did someone proceed with?
# ungrammatical question: What is someone recovering from?
# 287it [00:03, 89.45it/s]ungrammatical question: What isn't something give?
# ungrammatical question: What doesn't something comply with?
# 297it [00:03, 90.22it/s]ungrammatical question: What is someone involved in?
# ungrammatical question: What does something provide someone with?
# ungrammatical question: Where wasn't something be enabled?
# ungrammatical question: Who is be confused?
# 317it [00:03, 91.05it/s]ungrammatical question: What has someone elected someone as?
# 327it [00:03, 90.86it/s]ungrammatical question: What is someone known as?
# 337it [00:03, 90.77it/s]ungrammatical question: What did someone found?
# ungrammatical question: What did someone found?
# ungrammatical question: What is something involved in?
# ungrammatical question: What wasn't someone engage in?
# ungrammatical question: What did someone learn of?
# 347it [00:03, 90.08it/s]ungrammatical question: When did someone divided something?
# ungrammatical question: What did someone invite someone to do? ; all core args are present in core-role active question.
# ungrammatical question: what did someone invite someone to do? ; all core args are present in core-role active question.
# ungrammatical question: What wasn't someone enjoy?
# 357it [00:03, 90.26it/s]ungrammatical question: What was someone be operating?
# 367it [00:04, 91.59it/s]ungrammatical question: What is defeat?
# ungrammatical question: What isn't someone vote with?
# ungrammatical question: Who is be voting?
# ungrammatical question: Who is someone marry?
# 377it [00:04, 90.85it/s]ungrammatical question: What is founded?
# ungrammatical question: Where is something founded?
# ungrammatical question: Where is someone fly?
# ungrammatical question: Where did someone go?
# 387it [00:04, 91.32it/s]ungrammatical question: Who is someone communicate with?
# ungrammatical question: Who does someone study something with?
# ungrammatical question: Who is someone collaborating with?
# 397it [00:04, 91.22it/s]ungrammatical question: What does something go with?
# ungrammatical question: What is being fixed?
# 407it [00:04, 91.56it/s]ungrammatical question: What was something coming from?
# ungrammatical question: What has burned up?
# ungrammatical question: Where wasn't something be allowed?
# ungrammatical question: What wasn't something be allowed to do?
# ungrammatical question: What wasn't be allowed?
# 417it [00:04, 91.08it/s]ungrammatical question: what was someone given something to do? ; all core args are present in core-role active question.
# ungrammatical question: When was someone founded?
# 726it [00:07, 94.38it/s]ungrammatical question: How is something be prepared?
# ungrammatical question: How is something be prepared?
# ungrammatical question: Where is something be prepared?
# 736it [00:08, 94.08it/s]ungrammatical question: What did something free something from?
# ungrammatical question: What is something developing into?
# 746it [00:08, 93.10it/s]ungrammatical question: What did something come into?
# 766it [00:08, 95.74it/s]ungrammatical question: What was something regarded as?
# 776it [00:08, 94.55it/s]ungrammatical question: What is something specified by?
# ungrammatical question: What is something combined with?
# 786it [00:08, 68.58it/s]ungrammatical question: When did someone meet up?
# ungrammatical question: What is something described in?
# 795it [00:08, 73.29it/s]ungrammatical question: What can something be translated as?
# ungrammatical question: What is something translated as?
# ungrammatical question: What did someone come from?
# 804it [00:08, 77.03it/s]ungrammatical question: What is be proven?
# ungrammatical question: Who did someone sign something with?
# ungrammatical question: When did someone won something?
# ungrammatical question: What wond something?
# ungrammatical question: What did something won?
# ungrammatical question: What did someone buy something in?
# ungrammatical question: What did someone buy something in?
# 813it [00:08, 79.39it/s]ungrammatical question: Where did someone tyek something?
# ungrammatical question: What did someone tyek?
# ungrammatical question: What did someone work as?
# ungrammatical question: What is something prevented from?
# 822it [00:09, 81.18it/s]ungrammatical question: What is something rated as?
# 832it [00:09, 84.15it/s]ungrammatical question: What is something referred to as?
# ungrammatical question: What does something depend on?
# ungrammatical question: What is something known as?
# 841it [00:09, 82.03it/s]ungrammatical question: What was something correlated with?
# ungrammatical question: What is something interact with?
# ungrammatical question: What interact with something?
# 850it [00:09, 79.73it/s]ungrammatical question: What is something produced by?
# ungrammatical question: What is something pulled into?
# ungrammatical question: When does something shut up?
# ungrammatical question: What shuts up?
# 859it [00:09, 79.49it/s]ungrammatical question: What wasn't be identified?
# 868it [00:09, 80.18it/s]ungrammatical question: How was something carried up?
# ungrammatical question: How was something carried up?
# ungrammatical question: What was something turned into?
# 886it [00:09, 81.38it/s]ungrammatical question: What is something controlled by?
# ungrammatical question: What wasn't someone accomplish?
# 905it [00:10, 86.64it/s]ungrammatical question: What is something used as?
# 915it [00:10, 88.52it/s]ungrammatical question: What does something act as?
# ungrammatical question: What isn't something possess?
# ungrammatical question: What isn't possess something?
# ungrammatical question: What is something used in?
# 924it [00:10, 88.35it/s]ungrammatical question: What was something formed as?
# 944it [00:10, 90.55it/s]ungrammatical question: What is something depending on?
# ungrammatical question: What was find something?
# ungrammatical question: What was be found?
# 954it [00:10, 90.44it/s]ungrammatical question: What did something result in?
# ungrammatical question: What did something result in?
# 964it [00:10, 90.70it/s]ungrammatical question: What did someone persuade someone to do? ; all core args are present in core-role active question.
# ungrammatical question: what does someone persuade someone to do? ; all core args are present in core-role active question.
# ungrammatical question: What did someone invite someone to do? ; all core args are present in core-role active question.
# ungrammatical question: what did someone invite someone to do? ; all core args are present in core-role active question.
# 974it [00:10, 90.52it/s]ungrammatical question: What did someone myek?
# 984it [00:10, 91.18it/s]ungrammatical question: What is something referred of?
# 994it [00:11, 85.62it/s]ungrammatical question: What is something derived from?
# /home/nlp/kleinay/miniconda3/envs/seq2seq-qasrl/lib/python3.8/site-packages/qanom/evaluation/evaluate.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recall_mistakes['question'] = recall_mistakes['grt_role'].apply(lambda role: role.text)
# /home/nlp/kleinay/miniconda3/envs/seq2seq-qasrl/lib/python3.8/site-packages/qanom/evaluation/evaluate.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precision_mistakes['question'] = precision_mistakes['sys_role'].apply(lambda role: role.text)

# %% [markdown]
# Results above are rather low, and unlikely to be correct.
# So I suspect these is a bug in all 150 non-matching sentences where tokenization differs.
#
# Here let's try exclusing all these and see whether we get a more reasonable figure.

# %%
df_predictions_aligned = df_parsed_predictions.loc[~df_parsed_predictions.sentence.isin(missed_sents_pred)]
df_gold_aligned = df_gold.loc[~df_gold.sentence.isin(missed_sents)]

# eval_measures = evaluation.run_qanom_evaluation(df_predictions_aligned, df_gold_aligned)
# print(eval_measures[:2])
df_parsed_predictions.answer_range
# print(df_gold.shape)
# print(df_predictions_aligned.shape)
# print(df_gold_aligned.shape)
# print(df_parsed_predictions.columns)
# print(df_gold.columns)
# print(df_predictions_aligned.columns)
# print(df_gold_aligned.columns)
# Out:
# 0                 NaN
# 1                 0:4
# 2                 6:7
# 3         8:13~!~8:25
# 4           0:4~!~8:8
#             ...
# 5906            13:13
# 5907            14:18
# 5908            13:13
# 5909            18:18
# 5910    22:22~!~25:26
# Name: answer_range, Length: 5911, dtype: object

# %% [markdown]
# # Wandb API

# %% [markdown]
# ### Retrieve Aggragated Measures of sweep experiment

# %%
import pandas as pd 
from collections import defaultdict
import wandb
api = wandb.Api()

# Project is specified by <entity/project-name>
# all_runs = api.runs("kleinay/qasrl")
# runs = []

# for run in all_runs: 
#     # run.summary contains the output keys/values for metrics like accuracy.
#     # run.config contains the hyperparameters.
#     # run.name is the human-readable name of the run.
    
    
#     # Filter relevant runs
#     sweep_experiment_run_name = "linerization exp grid sweep qanom baseline"
#     if run.name != sweep_experiment_run_name:
#         continue

sweep_id = "pe0nvjzp"   # go to sweep overview, ID
exp_sweep = api.sweep(f"kleinay/qasrl/{sweep_id}")
runs = exp_sweep.runs

variable = "preprocess_output_func" # the independant variable whose effect we want to assess 
measures = ['Unlabled Arg f1', 'Unlabled Arg precision', 'Unlabled Arg recall',
            'Labled Arg f1', 'Labled Arg precision', 'Labled Arg recall']
agg_func = np.max
collected = {m:defaultdict(list) for m in measures} # collect measure by 

linearization2runs = defaultdict(list)
for run in runs:
    for measure in measures:
        if measure in run.summary:
            # get aggregated evaluations
            collected[measure][run.config[variable]].append(run.summary[measure])   
    linearization2runs[run.config["preprocess_output_func"]].append(run) 
             
    
aggregated = {measure: {variable_value: agg_func(collected[measure][variable_value])
                        for variable_value in collected[measure]}
              for measure in measures}

print(exp_sweep.name)

# get hyperparamters of best run per linearization method
hyperparamters = ("learning_rate", "gradient_accumulation_steps", "dropout_rate")
linearization2best_run = {}
for lin, runs in linearization2runs.items():
    results = [run.summary['Labled Arg f1'] if 'Labled Arg f1' in run.summary else -1 
               for run in runs ] 
    linearization2best_run[lin] = runs[np.argmax(results)]
linearization2best_hparams = {lin: {hparam: run.config[hparam] 
                                    for hparam in hyperparamters}
                              for lin, run in linearization2best_run.items()}
    
pp(linearization2best_hparams)
# Out:
# basic grid for linearization - qasrl-small dev (v2)
# { 'all_by_answer_ordering': { 'dropout_rate': 0.1,
#                               'gradient_accumulation_steps': 8,
#                               'learning_rate': 0.001},
#   'all_by_role_ordering': { 'dropout_rate': 0.1,
#                             'gradient_accumulation_steps': 14,
#                             'learning_rate': 0.001},
#   'all_shuffled': { 'dropout_rate': 0.15,
#                     'gradient_accumulation_steps': 8,
#                     'learning_rate': 0.001},
#   'permutate_all': { 'dropout_rate': 0.15,
#                      'gradient_accumulation_steps': 8,
#                      'learning_rate': 0.001},
#   'permutate_sample_fixed': { 'dropout_rate': 0.1,
#                               'gradient_accumulation_steps': 14,
#                               'learning_rate': 0.001},
#   'permutate_sample_num_of_qas': { 'dropout_rate': 0.1,
#                                    'gradient_accumulation_steps': 14,
#                                    'learning_rate': 0.001}}

# %%
pp(aggregated)
# Out:
# { 'Labled Arg f1': { 'all_by_answer_ordering': 0.4821536600120992,
#                      'all_by_role_ordering': 0.4877375843041079,
#                      'all_shuffled': 0.4808003530969545,
#                      'permutate_all': 0.4998511461744567,
#                      'permutate_sample_fixed': 0.47554957379991025,
#                      'permutate_sample_num_of_qas': 0.487527352297593},
#   'Labled Arg precision': { 'all_by_answer_ordering': 0.5198956294846706,
#                             'all_by_role_ordering': 0.5342511752854264,
#                             'all_shuffled': 0.513677811550152,
#                             'permutate_all': 0.5293190416141236,
#                             'permutate_sample_fixed': 0.5062082139446036,
#                             'permutate_sample_num_of_qas': 0.5299055613850997},
#   'Labled Arg recall': { 'all_by_answer_ordering': 0.4540327129159616,
#                          'all_by_role_ordering': 0.45346869712351945,
#                          'all_shuffled': 0.4608009024252679,
#                          'permutate_all': 0.4802594472645234,
#                          'permutate_sample_fixed': 0.4774393683023125,
#                          'permutate_sample_num_of_qas': 0.4712351945854484},
#   'Unlabled Arg f1': { 'all_by_answer_ordering': 0.6339987900786449,
#                        'all_by_role_ordering': 0.6351931330472104,
#                        'all_shuffled': 0.6255701044578491,
#                        'permutate_all': 0.6356725146198831,
#                        'permutate_sample_fixed': 0.6186328067326148,
#                        'permutate_sample_num_of_qas': 0.6211524434719182},
#   'Unlabled Arg precision': { 'all_by_answer_ordering': 0.6945441493180187,
#                               'all_by_role_ordering': 0.7030752916224814,
#                               'all_shuffled': 0.6693684566024991,
#                               'permutate_all': 0.6607818411097099,
#                               'permutate_sample_fixed': 0.6577523081821076,
#                               'permutate_sample_num_of_qas': 0.6910360029390155},
#   'Unlabled Arg recall': { 'all_by_answer_ordering': 0.5981387478849408,
#                            'all_by_role_ordering': 0.5961646926113932,
#                            'all_shuffled': 0.5995487873660462,
#                            'permutate_all': 0.6147772137619854,
#                            'permutate_sample_fixed': 0.6170332769317541,
#                            'permutate_sample_num_of_qas': 0.6003948110547095}}
